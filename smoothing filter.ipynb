# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("wallp.png")

smooth = cv2.blur(img, (7,7))

plt.imshow(cv2.cvtColor(smooth, cv2.COLOR_BGR2RGB))
plt.title("Average Blur")
plt.axis("off")
plt.show()
