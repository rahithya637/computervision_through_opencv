# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2.4.3)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (12.1.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: packaging>=21 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (0.5)

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Rotate image by 45 degrees
rotated = transform.rotate(img, 45)

# Display rotated image
io.imshow(rotated)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\302170257.py:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rotated)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\302170257.py:11: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Resize image to 300x300
resized = transform.resize(img, (300, 300))

# Display resized image
io.imshow(resized)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3993421284.py:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(resized)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3993421284.py:11: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Scale image to 50% of original size
scaled = transform.rescale(img, 0.5, channel_axis=-1)

# Display image
io.imshow(scaled)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3090378586.py:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(scaled)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3090378586.py:11: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io
import numpy as np

# Read image
img = io.imread("wallp.png")

# Flip horizontally
flip_h = np.fliplr(img)

# Display image
io.imshow(flip_h)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\2176432994.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(flip_h)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\2176432994.py:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io
import numpy as np

# Read image
img = io.imread("wallp.png")

# Flip vertically
flip_v = np.flipud(img)

# Display image
io.imshow(flip_v)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3361946384.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(flip_v)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3361946384.py:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Shift image by x=100 and y=50 pixels
tform = transform.AffineTransform(translation=(100, 50))

shifted = transform.warp(img, tform)

# Display image
io.imshow(shifted)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\929527994.py:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(shifted)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\929527994.py:13: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Affine transformation
tform = transform.AffineTransform(
    scale=(1.2, 1.2),
    rotation=0.3,
    translation=(50, 30)
)

affine_img = transform.warp(img, tform)

# Display image
io.imshow(affine_img)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\1149414592.py:16: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(affine_img)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\1149414592.py:17: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform

# Read image
img = io.imread("wallp.png")

# Apply shear
tform = transform.AffineTransform(shear=0.5)

sheared = transform.warp(img, tform)

# Display image
io.imshow(sheared)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3573134084.py:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(sheared)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\3573134084.py:13: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, transform
import matplotlib.pyplot as plt

# Read image
img = io.imread("wallp.png")

# Rotate image
rotated = transform.rotate(img, 45)

# Display both images
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(1,2,2)
plt.imshow(rotated)
plt.title("Rotated")

plt.show()

# %%
from skimage import io, transform
import numpy as np

# Read image
img = io.imread("wallp.png")

# Rotate image
img = transform.rotate(img, 30)

# Resize image
img = transform.resize(img, (400, 400))

# Flip horizontally
img = np.fliplr(img)

# Display final image
io.imshow(img)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\2500287814.py:17: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_13008\2500287814.py:18: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
