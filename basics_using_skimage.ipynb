# %%
# !pip install scikit-image

# %%
from skimage import io 
img = io.imread('wallp.png') 
io.imshow(img)
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\2805844960.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)

# %%
from skimage import io

# Read image
img = io.imread("wallp.png")

# Print image dimensions
print("Image Shape:", img.shape)
# Out:
# Image Shape: (1080, 1920, 4)

# %%
from skimage import io

img = io.imread("wallp.png")

height = img.shape[0]
width = img.shape[1]
channels = img.shape[2]

print("Height =", height)
print("Width =", width)
print("Channels =", channels)
# Out:
# Height = 1080
# Width = 1920
# Channels = 4

# %%
from skimage import io

img = io.imread("wallp.png")

print("Data Type:", img.dtype)
# Out:
# Data Type: uint8

# %%
from skimage import io

img = io.imread("wallp.png")

# Pixel at row 100, column 100
print(img[100,100])
# Out:
# [  0   2  23 255]

# %%
from skimage import io

img = io.imread("wallp.png")

print("Pixel 1:", img[50,50])
print("Pixel 2:", img[100,100])
print("Pixel 3:", img[200,200])
# Out:
# Pixel 1: [  1  26  34 255]
# Pixel 2: [  0   2  23 255]
# Pixel 3: [ 10  15  29 255]

# %%
from skimage import io

img = io.imread("wallp.png")

print("Shape :", img.shape)
print("Size  :", img.size)
print("Type  :", img.dtype)
# Out:
# Shape : (1080, 1920, 4)
# Size  : 8294400
# Type  : uint8

# %%
from skimage import io

img = io.imread("wallp.png")
#flattens image pixels
flat = img.flatten()

print(flat)
# Out:
# [  7   9  10 ...   6  34 226]

# %%
from skimage import io

img = io.imread("wallp.png")

print("Total Pixels =", img.size)
# Out:
# Total Pixels = 8294400

# %%
from skimage import io
import matplotlib.pyplot as plt

img = io.imread("wallp.png")

plt.imshow(img)
plt.title("Original Image")
plt.show()

# %%
from skimage import io

img = io.imread("wallp.png")

# Crop region
crop = img[100:400, 100:400]

io.imshow(crop)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\570978048.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(crop)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\570978048.py:9: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("wallp.png")

red = img[:,:,0]

io.imshow(red)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\745939287.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(red)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\745939287.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("wallp.png")

green = img[:,:,1]

io.imshow(green)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\634308778.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(green)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\634308778.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io

img = io.imread("wallp.png")

blue = img[:,:,2]

io.imshow(blue)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\1452231557.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(blue)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_12692\1452231557.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
