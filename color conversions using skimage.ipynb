# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2.4.3)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (12.1.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: packaging>=21 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-image) (0.5)

# %%
from skimage import io, color

img = io.imread("wallp.png")

# RGBA -> RGB
rgb = color.rgba2rgb(img)

# RGB -> Gray
gray = color.rgb2gray(rgb)

io.imshow(gray)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3884149537.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(gray)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3884149537.py:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to HSV
hsv = color.rgb2hsv(rgb)

# Display image
io.imshow(hsv)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3087438174.py:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(hsv)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3087438174.py:14: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to HSV
hsv = color.rgb2hsv(rgb)

# HSV back to RGB
rgb2 = color.hsv2rgb(hsv)

# Display image
io.imshow(rgb2)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\4228601913.py:16: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rgb2)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\4228601913.py:17: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to XYZ
xyz = color.rgb2xyz(rgb)

# Display image
io.imshow(xyz)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\1232574428.py:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(xyz)
# C:\Users\rahithya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.088754].
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\1232574428.py:14: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to XYZ
xyz = color.rgb2xyz(rgb)

# XYZ back to RGB
rgb2 = color.xyz2rgb(xyz)

# Display image
io.imshow(rgb2)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\4230831144.py:16: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rgb2)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\4230831144.py:17: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to LAB
lab = color.rgb2lab(rgb)

# Display image
io.imshow(lab)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3788892811.py:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(lab)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-107.85730020669489..100.0].
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3788892811.py:14: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
from skimage import io, color

# Read image
img = io.imread("wallp.png")

# RGBA to RGB
rgb = color.rgba2rgb(img)

# RGB to LAB
lab = color.rgb2lab(rgb)

# LAB back to RGB
rgb2 = color.lab2rgb(lab)

# Display image
io.imshow(rgb2)
io.show()
# Out:
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3206101426.py:16: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rgb2)
# C:\Users\rahithya\AppData\Local\Temp\ipykernel_17132\3206101426.py:17: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
